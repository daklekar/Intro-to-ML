# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sheet = pd.read_csv('C:\\Users\\dhruv\\Downloads\\D3.csv')

#Extracting Inputs
X0 = np.ones((len(sheet.X1),), dtype=float)
X1 = np.array(sheet.X1)
X2 = np.array(sheet.X2)
X3 = np.array(sheet.X3)

#Extracting Outputs
Y = np.array(sheet.Y)

#Selecting random values for the parameters for theta initially
_theta = [1,5,3,7]         #[theta_0 , theta_1, theta_2, theta_3]
theta = np.array(_theta, dtype=float)
Theta = theta.T

#The Hypothesis
h = np.ones((len(sheet.Y),), dtype=float)

#Concatenating X0 and X1 to get Ex= [X0|X1|X2|X3]
Ex = [X0, X1, X2, X3] 
Ex = np.array(Ex)

#Looping Structure
count = 0
while(count < 34):
    #h= [X].[Theta]
    h = np.matmul((Ex.T),(Theta.T))

    #Calculating the loss
    temp = (1/len(X1))*(h-Y)

    #Gradient
    Grad = np.matmul(Ex,temp)

    #Gradient decent used for prediction  Theta_new = Theta - &*[Grad]
    theta_new = Theta - 0.1*Grad
    a_theta = Theta
    Theta = theta_new
    
    count += 1
 
h1=h

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sheet = pd.read_csv('C:\\Users\\dhruv\\Downloads\\D3.csv')

#Extracting Inputs
X0 = np.ones((len(sheet.X1),), dtype=float)
X1 = np.array(sheet.X1)
X2 = np.array(sheet.X2)
X3 = np.array(sheet.X3)

#Extracting Outputs
Y = np.array(sheet.Y)

#Selecting random values for the parameters for theta initially
_theta = [1,5,3,7]         #[theta_0 , theta_1, theta_2, theta_3]
theta = np.array(_theta, dtype=float)
Theta = theta.T

#The Hypothesis
h = np.ones((len(sheet.Y),), dtype=float)

#Concatenating X0 and X1 to get Ex= [X0|X1|X2|X3]
Ex = [X0, X1, X2, X3] 
Ex = np.array(Ex)

#Looping Structure
count = 0
while(count < 34):
    #h= [X].[Theta]
    h = np.matmul((Ex.T),(Theta.T))

    #Calculating the loss
    temp = (1/len(X1))*(h-Y)

    #Gradient
    Grad = np.matmul(Ex,temp)

    #Gradient decent used for prediction  Theta_new = Theta - &*[Grad]
    theta_new = Theta - 0.05*Grad
    a_theta = Theta
    Theta = theta_new
    
    count += 1
    
h2 = h

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sheet = pd.read_csv('C:\\Users\\dhruv\\Downloads\\D3.csv')

#Extracting Inputs
X0 = np.ones((len(sheet.X1),), dtype=float)
X1 = np.array(sheet.X1)
X2 = np.array(sheet.X2)
X3 = np.array(sheet.X3)

#Extracting Outputs
Y = np.array(sheet.Y)

#Selecting random values for the parameters for theta initially
_theta = [1,5,3,7]         #[theta_0 , theta_1, theta_2, theta_3]
theta = np.array(_theta, dtype=float)
Theta = theta.T

#The Hypothesis
h = np.ones((len(sheet.Y),), dtype=float)

#Concatenating X0 and X1 to get Ex= [X0|X1|X2|X3]
Ex = [X0, X1, X2, X3] 
Ex = np.array(Ex)

#Looping Structure
count = 0     
while(count < 34):
    #h= [X].[Theta]
    h = np.matmul((Ex.T),(Theta.T))

    #Calculating the loss
    temp = (1/len(X1))*(h-Y)

    #Gradient
    Grad = np.matmul(Ex,temp)

    #Gradient decent used for prediction  Theta_new = Theta - &*[Grad]
    theta_new = Theta - 0.01*Grad
    a_theta = Theta
    Theta = theta_new
    
    count += 1
    
h3 = h

# %%
#Plots
fig, ax = plt.subplots(3,1, figsize=(20,50))

fig.suptitle('Effect of varying learning factor (Iterations are kept at 34 to see the comparison)')

ax[0].plot(h1,'y-+')
ax[0].set_adjustable
ax[0].set_title("a = 0.1")
ax[1].plot(h2,'y-+')
ax[1].set_title("a = 0.05")
ax[2].plot(h3,'y-+')
ax[2].set_title("a = 0.01")

ax[0].plot(Y,'b+')    #Ground Truth Plot
ax[1].plot(Y,'b+')    #Ground Truth Plot
ax[2].plot(Y,'b+')    #Ground Truth Plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sheet = pd.read_csv('C:\\Users\\dhruv\\Downloads\\D3.csv')

#Extracting Inputs
X0 = np.ones((len(sheet.X1),), dtype=float)
X1 = np.array(sheet.X1)
X2 = np.array(sheet.X2)
X3 = np.array(sheet.X3)

#Extracting Outputs
Y = np.array(sheet.Y)

#Selecting random values for the parameters for theta initially
_theta = [1,5,3,7]         #[theta_0 , theta_1, theta_2, theta_3]
theta = np.array(_theta, dtype=float)
Theta = theta.T

#The Hypothesis
h = np.ones((len(sheet.Y),), dtype=float)

#Concatenating X0 and X1 to get Ex= [X0|X1|X2|X3]
Ex = [X0, X1, X2, X3] 
Ex = np.array(Ex)

#Looping Structure
count = 0
while(count < 500):
    #h= [X].[Theta]
    h = np.matmul((Ex.T),(Theta.T))

    #Calculating the loss
    temp = (1/len(X1))*(h-Y)

    #Gradient
    Grad = np.matmul(Ex,temp)

    #Gradient decent used for prediction  Theta_new = Theta - &*[Grad]
    theta_new = Theta - 0.1*Grad
    a_theta = Theta
    Theta = theta_new
    
    count += 1
    
plt.plot(h,'r--')
plt.plot(Y,'b+')

# %%
#Analyzing smallest loss to acquire least iterations
plt.plot(temp*len(X1))
#plt.plot(grad)
